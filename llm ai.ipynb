# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import csv
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv(r"C:\Users\pgupt\Desktop\mix-data.csv")

# %%
X = data['name']
y = data['label']

# %%
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(data['name'].values.astype('U'))

# %%
X_train_name, X_test_name, y_train_name, y_test_name = train_test_split(X_vectorized, y, test_size=0.2, random_state=42,stratify=y)

# %%
data['label'].value_counts()
# Out:
# 0    108470
# 1     67426
# Name: label, dtype: int64

# %%
y_test_name.value_counts()
# Out:
# 0    21694
# 1    13486
# Name: label, dtype: int64

# %%
#decision tree
classifierdt_name =DecisionTreeClassifier()
classifierdt_name.fit(X_train_name, y_train_name)
# Out:
# DecisionTreeClassifier()

# %%
#support vector machine
classifiersvc_name =SVC()
classifiersvc_name.fit(X_train_name, y_train_name)
# Out:
# SVC()

# %%
#random forest
classifierrf_name =RandomForestClassifier()
classifierrf_name.fit(X_train_name, y_train_name)
# Out:
# RandomForestClassifier()

# %%
#logistic regression
classifierlr_name =LogisticRegression()
classifierlr_name.fit(X_train_name, y_train_name)
# Out:
# LogisticRegression()

# %%
#KNN
classifierknn_name =KNeighborsClassifier()
classifierknn_name.fit(X_train_name, y_train_name)
# Out:
# KNeighborsClassifier()

# %%
y_preddt_name = classifierdt_name.predict(X_test_name)
y_predsvc_name = classifiersvc_name.predict(X_test_name)
y_predrf_name = classifierrf_name.predict(X_test_name)
y_predlr_name = classifierlr_name.predict(X_test_name)
y_predknn_name = classifierknn_name.predict(X_test_name)

# %%
accuracydt_name = accuracy_score(y_test_name, y_preddt_name)
print("Accuracy decision tree:", accuracydt_name)

accuracysvc_name = accuracy_score(y_test_name, y_predsvc_name)
print("Accuracy svm :", accuracysvc_name)

accuracyrf_name = accuracy_score(y_test_name, y_predrf_name)
print("Accuracy random forest:", accuracyrf_name)

accuracylr_name = accuracy_score(y_test_name, y_predlr_name)
print("Accuracy logistic regresion:", accuracylr_name)

accuracyknn_name = accuracy_score(y_test_name, y_predknn_name)
print("Accuracy KNN:", accuracyknn_name)
# Out:
# Accuracy decision tree: 0.6041216600341103
# Accuracy svm : 0.9428084138715179
# Accuracy random forest: 0.63121091529278
# Accuracy logistic regresion: 0.9442296759522456
# Accuracy KNN: 0.9476122797043774

# %%
def predict_name(name):
    if any(char.isdigit() for char in name):
        return "Invalid Name"
    name_vectorized = vectorizer.transform([name])
    predictions = []
    
    classifiers = [("Decision Tree ",classifierdt_name), 
                   ("Support Vector ",classifiersvc_name),
                   ("Random Forest ",classifierrf_name), 
                   ("Logistic Regression ",classifierlr_name),
                   ("KNN ",classifierknn_name)]
    
    for name,classifier in classifiers:
        prediction = classifier.predict(name_vectorized)
        if prediction[0] == 1:
            predictions.append(f"{name}: Valid Name")
        else: 
            predictions.append(f"{name}: Invalid Name")
    
    return "\n".join(predictions)

# %%
def check_valid_name(name):
    if any(char.isdigit() for char in name):
        return "Invalid Name"
    else:
        return "valid"

# %%
check_valid_name("hello@gmail.com")
# Out:
# 'valid'

# %%
def predict_name_most_occurance(name):
    if any(char.isdigit() for char in name):
        return "Invalid Name"
    name_vectorized = vectorizer.transform([name])
    predictions = []
    
    classifiers = [("Decision Tree", classifierdt_name), 
                   ("Support Vector", classifiersvc_name),
                   ("Random Forest", classifierrf_name), 
                   ("Logistic Regression", classifierlr_name), 
                   ("KNN", classifierknn_name)]
    
    for _, classifier in classifiers:
        prediction = classifier.predict(name_vectorized)
        predictions.append(prediction[0])
    
    valid_count = predictions.count(1)
    invalid_count = predictions.count(0)
    
    if valid_count > invalid_count:
        return "Valid Name"
    else:
        return "Invalid Name"

# %% [markdown]
# # Gender Prediction

# %%
#fill not name data as label 2
fill_column = 'gender'
data[fill_column].fillna(2, inplace=True)
data.to_csv(r"C:\Users\pgupt\Desktop\mix_data.csv", index=False)

# %%
#replace M and F with label M=0 and F=1
data['gender'].replace({'m': 0, 'f': 1}, inplace=True)
data.to_csv(r"C:\Users\pgupt\Desktop\mix_data.csv", index=False)

# %%
X = data['name']
y = data['gender']

# %%
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(data['name'].values.astype('U'))

# %%
X_train_gender, X_test_gender, y_train_gender, y_test_gender = train_test_split(X_vectorized, y, test_size=0.2, random_state=42,stratify=y)

# %%
data['gender'].value_counts()
# Out:
# 2    108459
# 0     36593
# 1     30844
# Name: gender, dtype: int64

# %%
#decision tree
classifierdt_gender =DecisionTreeClassifier()
classifierdt_gender.fit(X_train_gender, y_train_gender)
# Out:
# DecisionTreeClassifier()

# %%
#support vector machine
classifiersvc_gender =SVC()
classifiersvc_gender.fit(X_train_gender, y_train_gender)
# Out:
# SVC()

# %%
#random forest
classifierrf_gender =RandomForestClassifier()
classifierrf_gender.fit(X_train_gender, y_train_gender)
# Out:
# RandomForestClassifier()

# %%
#logistic regression
classifierlr_gender =LogisticRegression()
classifierlr_gender.fit(X_train_gender, y_train_gender)
# Out:
# C:\Users\pgupt\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#KNN
classifierknn_gender =KNeighborsClassifier()
classifierknn_gender.fit(X_train_gender, y_train_gender)
# Out:
# KNeighborsClassifier()

# %%
y_preddt_gender = classifierdt_gender.predict(X_test_gender)
y_predsvc_gender = classifiersvc_gender.predict(X_test_gender)
y_predrf_gender = classifierrf_gender.predict(X_test_gender)
y_predlr_gender = classifierlr_gender.predict(X_test_gender)
y_predknn_gender = classifierknn_gender.predict(X_test_gender)

# %%
accuracydt_gender = accuracy_score(y_test_gender, y_preddt_gender)
print("Accuracy decision tree:", accuracydt_gender)

accuracysvc_gender = accuracy_score(y_test_gender, y_predsvc_gender)
print("Accuracy svm :", accuracysvc_gender)

accuracyrf_gender = accuracy_score(y_test_gender, y_predrf_gender)
print("Accuracy random forest:", accuracyrf_gender)

accuracylr_gender = accuracy_score(y_test_gender, y_predlr_gender)
print("Accuracy logistic regresion:", accuracylr_gender)

accuracyknn_gender = accuracy_score(y_test_gender, y_predknn_gender)
print("Accuracy KNN:", accuracyknn_gender)
# Out:
# Accuracy decision tree: 0.6405343945423536
# Accuracy svm : 0.7895679363274588
# Accuracy random forest: 0.7410744741330302
# Accuracy logistic regresion: 0.7992325184764071
# Accuracy KNN: 0.7946844798180784

# %%
def predict_gender(name):
    if any(char.isdigit() for char in name):
        return "Not a Valid Name Cannot Determine Gender"
    if result_name=="Invalid Name":
        return "Not a Valid Name Cannot Determine Gender"
    else:
        return gender_predn_model(name)

# %%
def gender_predn_model(name):
    name_vectorized = vectorizer.transform([name])
    predictions = []
    
    classifiers = [("Decision Tree ",classifierdt_gender),
                   ("Support Vector ",classifiersvc_gender),
                   ("Random Forest ",classifierrf_gender), 
                   ("Logistic Regression ",classifierlr_gender),
                   ("KNN ",classifierknn_gender)]
    
    for name,classifier in classifiers:
        prediction = classifier.predict(name_vectorized)
        if prediction[0] == 1:
            predictions.append(f"{name}: Female")
        else: 
            predictions.append(f"{name}: Male")
    
    return "\n".join(predictions)

# %%
def predict_gender_most_occurance(name):
    if any(char.isdigit() for char in name):
        return "Not a Valid Name Cannot Determine Gender"
    if result_name=="Invalid Name":
        return "Not a Valid Name Cannot Determine Gender"
    
    name_vectorized = vectorizer.transform([name])
    predictions = []
    
    classifiers = [("Decision Tree", classifierdt_gender),
                   ("Support Vector", classifiersvc_gender),
                   ("Random Forest", classifierrf_gender), 
                   ("Logistic Regression", classifierlr_gender),
                   ("KNN", classifierknn_gender)]
    
    for _, classifier in classifiers:
        prediction = classifier.predict(name_vectorized)
        predictions.append(prediction[0])
    
    female_count = predictions.count(1)
    male_count = predictions.count(0)
    
    if female_count > male_count:
        return "Female"
    else:
        return "Male"

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"****** Prediction for '{name}': {result_name} ******")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"****** Gender of '{name}': {result_gender} ******")
# Out:
# Enter a name: hello
# Decision Tree : Invalid Name
# Support Vector : Valid Name
# Random Forest : Invalid Name
# Logistic Regression : Valid Name
# KNN : Invalid Name
# ****** Prediction for 'hello': Invalid Name ******
# Not a Valid Name Cannot Determine Gender
# ****** Gender of 'hello': Not a Valid Name Cannot Determine Gender ******

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"****** Prediction for '{name}': {result_name} ******")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"****** Gender of '{name}': {result_gender} ******")
# Out:
# Enter a name: richard
# Decision Tree : Invalid Name
# Support Vector : Invalid Name
# Random Forest : Invalid Name
# Logistic Regression : Invalid Name
# KNN : Invalid Name
# ****** Prediction for 'richard': Invalid Name ******
# Not a Valid Name Cannot Determine Gender
# ****** Gender of 'richard': Not a Valid Name Cannot Determine Gender ******

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"Hurray !!!!!!!!!!!!!!!!!!!! Prediction for '{name}': {result_name}")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"Hurray !!!!!!!!!!!!!!!!!!!! Gender of '{name}': {result_gender}")
# Out:
# Enter a name: priyanshu
# Decision Tree : Valid Name
# Support Vector : Valid Name
# Random Forest : Valid Name
# Logistic Regression : Valid Name
# KNN : Valid Name
# Hurray !!!!!!!!!!!!!!!!!!!! Prediction for 'priyanshu': Valid Name
# Decision Tree : Male
# Support Vector : Male
# Random Forest : Male
# Logistic Regression : Male
# KNN : Male
# Hurray !!!!!!!!!!!!!!!!!!!! Gender of 'priyanshu': Male

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"Hurray !!!!!!!!!!!!!!!!!!!! Prediction for '{name}': {result_name}")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"Hurray !!!!!!!!!!!!!!!!!!!! Gender of '{name}': {result_gender}")
# Out:
# Enter a name: priyanshu@gmail.com
# Decision Tree : Valid Name
# Support Vector : Invalid Name
# Random Forest : Invalid Name
# Logistic Regression : Invalid Name
# KNN : Valid Name
# Hurray !!!!!!!!!!!!!!!!!!!! Prediction for 'priyanshu@gmail.com': Invalid Name
# Not a Valid Name Cannot Determine Gender
# Hurray !!!!!!!!!!!!!!!!!!!! Gender of 'priyanshu@gmail.com': Not a Valid Name Cannot Determine Gender

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"****** Prediction for '{name}': {result_name} ******")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"****** Gender of '{name}': {result_gender} ******")
# Out:
# Enter a name: anshu
# Decision Tree : Valid Name
# Support Vector : Valid Name
# Random Forest : Valid Name
# Logistic Regression : Valid Name
# KNN : Valid Name
# ****** Prediction for 'anshu': Valid Name ******
# Decision Tree : Female
# Support Vector : Female
# Random Forest : Female
# Logistic Regression : Female
# KNN : Female
# ****** Gender of 'anshu': Female ******

# %%
name = input("Enter a name: ")
result_name=predict_name(name)
print(result_name)
result_name = predict_name_most_occurance(name)
print(f"****** Prediction for '{name}': {result_name} ******")
result_gender=predict_gender(name)
print(result_gender)
result_gender=predict_gender_most_occurance(name)
print(f"****** Gender of '{name}': {result_gender} ******")
# Out:
# Enter a name: sparsh
# Decision Tree : Valid Name
# Support Vector : Valid Name
# Random Forest : Valid Name
# Logistic Regression : Valid Name
# KNN : Valid Name
# ****** Prediction for 'sparsh': Valid Name ******
# Decision Tree : Male
# Support Vector : Male
# Random Forest : Male
# Logistic Regression : Male
# KNN : Male
# ****** Gender of 'sparsh': Male ******
